# %%
import pandas as pd 
import numpy as np
import array as arr

pd.options.mode.chained_assignment = None
Output = pd.DataFrame()
Product_Master = pd.read_csv('Desktop/Recommender/Project 1/Product Master_Online.csv')
Product_ID = Product_Master.Productid

Customer_Data = pd.read_csv('Desktop/Recommender/Project 1/Customer Data.csv')
Prod_ID = Customer_Data.ProductId
User_ID = Customer_Data.UserId
Users = User_ID.unique()
Products = Prod_ID.unique()
Users.sort()

Cust1 = pd.read_csv('Desktop/Recommender/Project 1/Cust1.csv')
Cust2 = pd.read_csv('Desktop/Recommender/Project 1/Cust2.csv')
Cust_Top = pd.read_csv('Desktop/Recommender/Project 1/Cust_Top copy.csv')
Top_Users = Cust_Top.UserId
Top_Users = Top_Users.unique()
Top_Users.sort()
Top_Products = Cust_Top.ProductId
Top_Products = Top_Products.unique()
Top_Products.sort()
#df_inner = pd.merge(Cust1, Cust2, on='UserId', how='inner')
#df_inner.to_csv('Desktop/Recommender/Project 1/Total Output3.csv')

#print(len(Top_Users.unique()))
#print(len(Top_Products.unique()))

#Top_Data = pd.DataFrame(index=Top_Users,columns=Top_Products)
#Top_Data.fillna(0)


#for j in df_inner.ProductId_y:
    #y=0
    #for k in df_inner.ProductId_x:
        #if(df_inner.iat[z,2]) == j and (df_inner.iat[y,1]) != j:
            #Cust.at[j,k] += 1
        #y=y+1
    #z=z+1

#Top_Data

            

#print(Users)
#print(Prod_ID)
#O1=pd.read_csv('Desktop/Recommender/Project 1/Total Output2.csv')


#X = Customer_Data.at[2,'ProductId']
#print(X)
#Product = Prod_ID.unique()
#k = len(Product)
#User_List = pd.DataFrame()
#for i in Product:
    #if k < len(Product)+1:
        #for j in range(len(User_ID)):
            #if Customer_Data.at[k,'ProductId'] == Customer_Data.at[j,'UserId']:
                #User_List.append(Customer_Data.at[j,'UserId'])
            #else:
                #User_List.append([0])
#k = k+1
    #User_List.append(i)
    #if i not in User_List:

    

#print(User_List)
#print(arr)
#print(product)

table = pd.pivot_table(Cust_Top, index = Top_Products)
#table = table.fillna(0)



#similarity calculation
#from scipy import sparse
#sparse_matrix = sparse.csr_matrix(table)
#from sklearn.metrics.pairwise import pairwise_distances
#recommender_matrix = pairwise_distances(sparse_matrix,metric="cosine")
#recommender_matrix = 1-recommender_matrix

#Users=Top_Users.unique()
#Products=Top_Products.unique()
#final = pd.DataFrame(recommender_matrix,index=Users,columns=Users)
#Output = pd.DataFrame(index = Users,columns = Products)
#Output = Output.fillna(0)



#Output = Output.append(recommender_matrix)
#Output = pd.DataFrame(recommender_matrix)
#print(table)
#Output.to_csv('Desktop/Recommender/Project 1/Total Output3.csv')
#final.to_csv('Desktop/Recommender/Project 1/recommendation_matrix.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-3f550ebc5946> in <module>
#      73 #print(product)
#      74
# ---> 75 table = pd.pivot_table(Cust_Top, index = Top_Products)
#      76 #table = table.fillna(0)
#      77 table
#
# /Users/Tanmoy/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     109         values = list(values)
#     110
# --> 111     grouped = data.groupby(keys, observed=observed)
#     112     agged = grouped.agg(aggfunc)
#     113     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# /Users/Tanmoy/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
# ...
